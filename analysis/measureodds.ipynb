# %% [markdown]
# # Prediction Quality (DraftKings version)

# %%
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %%
def compute_winloss(odds,input=100,houseedge=0.01):
    return input*(1.0/odds)*(1-houseedge)


predictiondir = 'predictions/archive/'
def get_validation(month,day,year='2024'):
    validation = pd.read_csv(predictiondir + '{2}-{0:02d}-{1:02d}validation.csv'.format(month,day,year))
    return validation

team_translation = {'TOR':'Toronto Blue Jays','MIN':'Minnesota Twins','MIL':'Milwaukee Brewers','CHC':'Chicago Cubs','CIN':'Cincinnati Reds','STL':'St. Louis Cardinals','CLE':'Cleveland Guardians','DET':'Detroit Tigers','HOU':'Houston Astros','TEX':'Texas Rangers','LAA':'Los Angeles Angels','OAK':'Oakland Athletics','SEA':'Seattle Mariners','ARI':'Arizona Diamondbacks','COL':'Colorado Rockies','LAD':'Los Angeles Dodgers','SD':'San Diego Padres','SF':'San Francisco Giants','BAL':'Baltimore Orioles','BOS':'Boston Red Sox','NYY':'New York Yankees','TB':'Tampa Bay Rays','ATL':'Atlanta Braves','MIA':'Miami Marlins','NYM':'New York Mets','PHI':'Philadelphia Phillies','PIT':'Pittsburgh Pirates','WAS':'Washington Nationals','KC':'Kansas City Royals','CWS':'Chicago White Sox'}
oddsdir = 'data/2024/odds/archive/'
def get_odds(month,day,hour='12',year='2024'):
    odds = pd.read_csv(oddsdir + 'dk_{3}-{0:02d}-{1:02d}-{2}.csv'.format(month,day,hour,year))
    odds['hometeamfull'] = odds['hometeam'].apply(lambda x: team_translation[x])
    odds['awayteamfull'] = odds['awayteam'].apply(lambda x: team_translation[x])
    return odds

# test set
O = get_odds(5,12)
V = get_validation(5,13)

# %%
VO = pd.merge(V,O,left_on=['hometeamfull','awayteamfull'],right_on=['hometeamfull','awayteamfull'])
VO
# Out:
#         date_x          hometeamfull  hometeamwin  hometeamscore  \
# 0   2024-05-12     Baltimore Orioles        False              2
# 1   2024-05-12        Boston Red Sox         True              3
# 2   2024-05-12    Pittsburgh Pirates        False              4
# 3   2024-05-12     Toronto Blue Jays        False              1
# 4   2024-05-12        Detroit Tigers        False              3
# 5   2024-05-12         Miami Marlins         True              7
# 6   2024-05-12        Tampa Bay Rays        False              6
# 7   2024-05-12     Chicago White Sox        False              0
# 8   2024-05-12     Milwaukee Brewers        False              3
# 9   2024-05-12      Colorado Rockies         True              3
# 10  2024-05-12  San Francisco Giants         True              6
# 11  2024-05-12    Los Angeles Angels        False              2
# 12  2024-05-12      San Diego Padres         True              4
# 13  2024-05-12      Seattle Mariners         True              8
# 14  2024-05-12         New York Mets         True              4
#
#     hometeamodds           awayteamfull  awayteamwin  awayteamscore  \
# 0          0.511   Arizona Diamondbacks         True              9
# 1          0.455   Washington Nationals        False              2
# 2          0.427           Chicago Cubs         True              5
# 3          0.410        Minnesota Twins         True              5
# 4          0.595         Houston Astros         True              9
# 5          0.292  Philadelphia Phillies        False              6
# 6          0.500       New York Yankees         True             10
# 7          0.539    Cleveland Guardians         True              7
# 8          0.719    St. Louis Cardinals         True              4
# 9          0.511          Texas Rangers        False              1
# 10         0.578        Cincinnati Reds        False              5
# 11         0.516     Kansas City Royals         True              4
# 12         0.359    Los Angeles Dodgers        False              0
# 13         0.545      Oakland Athletics        False              4
# 14         0.477         Atlanta Braves        False              3
#
#     awayteamodds hometeam awayteam  hometeamodds_dk  awayteamodds_dk    ou  \
# 0          0.489      BAL      ARI         0.532468         0.467532   8.0
# 1          0.545      BOS      WAS         0.582993         0.417007   8.0
# 2          0.573      PIT      CHC         0.482636         0.517364   8.5
# 3          0.590      TOR      MIN         0.448559         0.551441   8.5
# 4          0.405      DET      HOU         0.482636         0.517364   7.5
# 5          0.708      MIA      PHI         0.330993         0.669007   7.0
# 6          0.500       TB      NYY         0.448559         0.551441   8.0
# 7          0.461      CWS      CLE         0.400361         0.599639   9.0
# 8          0.281      MIL      STL         0.582993         0.417007   8.0
# 9          0.489      COL      TEX         0.417007         0.582993  11.0
# 10         0.422       SF      CIN         0.542744         0.457256   8.0
# 11         0.484      LAA       KC         0.448559         0.551441   8.0
# 12         0.641       SD      LAD         0.467532         0.532468   8.5
# 13         0.455      SEA      OAK         0.669007         0.330993   7.5
# 14         0.523      NYM      ATL         0.467532         0.532468   8.0
#
#          homepitcher        awaypitcher                        date_y
# 0        Dean Kremer         Zac Gallen  2024-05-12T17:35:00.0000000Z
# 1       Brayan Bello     MacKenzie Gore  2024-05-12T17:35:00.0000000Z
# 2      Bailey Falter     Kyle Hendricks  2024-05-12T17:35:00.0000000Z
# 3        Alek Manoah        Bailey Ober  2024-05-12T17:37:00.0000000Z
# 4      Jack Flaherty   Justin Verlander  2024-05-12T17:40:00.0000000Z
# 5    Braxton Garrett       Zack Wheeler  2024-05-12T17:40:00.0000000Z
# 6    Tyler Alexander           Luis Gil  2024-05-12T17:40:00.0000000Z
# 7     Michael Soroka  Logan Allen (CLE)  2024-05-12T18:10:00.0000000Z
# 8       Bryse Wilson      Miles Mikolas  2024-05-12T18:10:00.0000000Z
# 9      Dakota Hudson         Jose Urena  2024-05-12T19:10:00.0000000Z
# 10     Kyle Harrison     Frankie Montas  2024-05-12T20:05:00.0000000Z
# 11  Patrick Sandoval          Seth Lugo  2024-05-12T20:07:00.0000000Z
# 12        Yu Darvish     Walker Buehler  2024-05-12T20:10:00.0000000Z
# 13     Luis Castillo          Alex Wood  2024-05-12T20:10:00.0000000Z
# 14     Luis Severino        Bryce Elder  2024-05-12T23:10:00.0000000Z

# %%
# what is our average difference in odds?
VO['odds_comparison'] = VO['hometeamodds'] - VO['hometeamodds_dk']

ovalues = VO['odds_comparison'].values
plt.plot(ovalues[np.argsort(ovalues)],color='black')

# %%
outlierthreshold = 0.15
winthreshold = 0.6
pot = 1000.0
betsize = 100.
houseedge = 0.01

def run_bets(VO,pot,outlierthreshold,winthreshold,betsize,houseedge):

    for game in range(0,len(VO['odds_comparison'].values)):
        oddsdiff = VO['odds_comparison'].values[game]
        homeodds = VO['hometeamodds'].values[game]
        homeoddsdk = VO['hometeamodds_dk'].values[game]
        homewin = VO['hometeamwin'].values[game]
        hometeam = VO['hometeamfull'].values[game]
        awayteam = VO['awayteamfull'].values[game]
        dateval = VO['date_x'].values[game]

        # we are favouring the home team: bet them
        if (oddsdiff > outlierthreshold) & (homeodds > winthreshold):
            print('{4}: Betting on {0} to beat {1} with odds {2}: {3} ({5})'.format(hometeam,awayteam,homeoddsdk,homewin,dateval,np.round(pot,0)))

            if homewin:
                pot += compute_winloss(homeoddsdk,input=betsize,houseedge=houseedge) - betsize
            else:
                pot -= betsize

        # we are favouring the away team: bet them
        if (oddsdiff < -outlierthreshold) & (homeodds < 1-winthreshold):
            print('{4}: Betting on {0} to beat {1} with odds {2}: {3} ({5})'.format(awayteam,hometeam,homeoddsdk,not homewin,dateval,np.round(pot,0)))

            if not homewin:
                pot += compute_winloss(homeoddsdk,input=betsize,houseedge=houseedge) - betsize
            else:
                pot -= betsize

        
    return pot
        

print(run_bets(VO,pot,outlierthreshold,winthreshold,betsize,houseedge))
# Out:
# 1000.0

# %%
# get the days in the season
date_range = pd.date_range(start='2024-05-11', end='2024-09-29')
days_list = [(date.month, date.day) for date in date_range]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 VO['odds_comparison'].values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
totalo,totalg = 0,0
ovalues = []
pot = 1000.0
outlierthreshold = 0.15
winthreshold = 0.6


for day_indx,day in enumerate(days_list):
    try:
        O = get_odds(*day,hour='12')
        V = get_validation(*days_list[day_indx+1])
        VO = pd.merge(V,O,left_on=['hometeamfull','awayteamfull'],right_on=['hometeamfull','awayteamfull'])
        VO['checkou'] = (VO['hometeamscore'] + VO['awayteamscore']) > VO['ou']
        totalo += VO['checkou'].sum()
        totalg += VO['checkou'].size

        # check the prediction values
        # what we think, versus what the bookies think
        # if positive, we think the home team will win more than the bookies
        # so we should bet on the home team. if negative, we should bet on the away team
        # with some threshold (and have to predict home team to actually win)
        VO['odds_comparison'] = VO['hometeamodds'] - VO['hometeamodds_dk']

        pot = run_bets(VO,pot,outlierthreshold,winthreshold,betsize,houseedge)
        plt.scatter(day_indx,pot-1000.,color='black')

        ovalues.extend(VO['odds_comparison'].values)
    except:
        print(day)


plt.xlabel('Day')
plt.ylabel('Winnings')
plt.axis([0,70,-1000,1000])
print(totalo,totalg,totalo/totalg)
# Out:
# 2024-05-11: Betting on Minnesota Twins to beat Toronto Blue Jays with odds 0.5829926396165348: False (1000.0)
# 2024-05-11: Betting on Washington Nationals to beat Boston Red Sox with odds 0.5933697527596193: False (900.0)
# 2024-05-11: Betting on Philadelphia Phillies to beat Miami Marlins with odds 0.4572564613405057: True (800.0)
# 2024-05-14: Betting on Los Angeles Angels to beat St. Louis Cardinals with odds 0.4365079376463042: False (917.0)
# 2024-05-17: Betting on Colorado Rockies to beat San Francisco Giants with odds 0.5996387716075958: False (817.0)
# 2024-05-18: Betting on Colorado Rockies to beat San Francisco Giants with odds 0.6369041809336118: False (717.0)
# 2024-05-19: Betting on Cleveland Guardians to beat Minnesota Twins with odds 0.5217391295274103: True (617.0)
# 2024-05-19: Betting on Miami Marlins to beat New York Mets with odds 0.4365079376463042: False (706.0)
# 2024-05-19: Betting on Detroit Tigers to beat Arizona Diamondbacks with odds 0.5829926396165348: False (606.0)
# 2024-05-20: Betting on Cleveland Guardians to beat New York Mets with odds 0.5427435386594943: True (506.0)
# 2024-05-21: Betting on Cleveland Guardians to beat New York Mets with odds 0.5324675324675324: True (589.0)
# 2024-05-21: Betting on Washington Nationals to beat Minnesota Twins with odds 0.3775334495818208: False (675.0)
# 2024-05-21: Betting on Colorado Rockies to beat Oakland Athletics with odds 0.5514411134008372: False (575.0)
# 2024-05-23: Betting on San Francisco Giants to beat Pittsburgh Pirates with odds 0.5933697527596193: True (475.0)
# (5, 24)
# (5, 25)
# 2024-05-26: Betting on Kansas City Royals to beat Tampa Bay Rays with odds 0.5260865840488141: False (541.0)
# 2024-05-29: Betting on Milwaukee Brewers to beat Chicago Cubs with odds 0.4485588865991627: True (441.0)
# 2024-05-30: Betting on Washington Nationals to beat Atlanta Braves with odds 0.6636481233329261: True (562.0)
# 2024-05-31: Betting on Detroit Tigers to beat Boston Red Sox with odds 0.6037569700561242: False (611.0)
# 2024-06-05: Betting on Baltimore Orioles to beat Toronto Blue Jays with odds 0.5324675324675324: False (511.0)
# 2024-06-06: Betting on Baltimore Orioles to beat Toronto Blue Jays with odds 0.5217391295274103: False (411.0)
# 2024-06-07: Betting on Boston Red Sox to beat Chicago White Sox with odds 0.5043297536554499: False (311.0)
# 2024-06-08: Betting on Pittsburgh Pirates to beat Minnesota Twins with odds 0.4782608704725898: True (211.0)
# 2024-06-09: Betting on Cincinnati Reds to beat Chicago Cubs with odds 0.4739134159511858: False (318.0)
# 2024-06-09: Betting on Cleveland Guardians to beat Miami Marlins with odds 0.4956702463445501: True (218.0)
# 2024-06-09: Betting on Milwaukee Brewers to beat Detroit Tigers with odds 0.6092362331597097: False (318.0)
# 2024-06-11: Betting on Baltimore Orioles to beat Atlanta Braves with odds 0.4572564613405057: True (218.0)
# 2024-06-12: Betting on Baltimore Orioles to beat Atlanta Braves with odds 0.5514411134008372: True (335.0)
# 2024-06-13: Betting on Baltimore Orioles to beat Atlanta Braves with odds 0.5217391295274103: False (414.0)
# 2024-06-13: Betting on Washington Nationals to beat Detroit Tigers with odds 0.5829926396165348: False (314.0)
# 2024-06-15: Betting on Washington Nationals to beat Miami Marlins with odds 0.5260865840488141: True (214.0)
# 2024-06-16: Betting on Washington Nationals to beat Miami Marlins with odds 0.5217391295274103: True (302.0)
# 2024-06-16: Betting on Detroit Tigers to beat Houston Astros with odds 0.5514411134008372: False (392.0)
# 2024-06-17: Betting on New York Mets to beat Texas Rangers with odds 0.5427435386594943: True (292.0)
# 2024-06-18: Betting on New York Mets to beat Texas Rangers with odds 0.5: True (374.0)
# 2024-06-19: Betting on Seattle Mariners to beat Cleveland Guardians with odds 0.5514411134008372: False (472.0)
# 2024-06-19: Betting on New York Mets to beat Texas Rangers with odds 0.5: False (372.0)
# 2024-06-21: Betting on New York Mets to beat Chicago Cubs with odds 0.5634920623536956: True (272.0)
# 2024-06-21: Betting on Atlanta Braves to beat New York Yankees with odds 0.4956702463445501: True (348.0)
# 2024-06-21: Betting on Milwaukee Brewers to beat San Diego Padres with odds 0.5829926396165348: False (448.0)
# 2024-06-22: Betting on New York Mets to beat Chicago Cubs with odds 0.5173641257223942: False (348.0)
# 2024-06-22: Betting on Atlanta Braves to beat New York Yankees with odds 0.5634920623536956: False (248.0)
# 2024-06-23: Betting on Atlanta Braves to beat New York Yankees with odds 0.5043297536554499: True (148.0)
# 2024-06-23: Betting on Cleveland Guardians to beat Toronto Blue Jays with odds 0.5108342368128271: True (244.0)
# 2024-06-25: Betting on Cleveland Guardians to beat Baltimore Orioles with odds 0.5634920623536956: True (338.0)
# 2024-06-25: Betting on New York Mets to beat New York Yankees with odds 0.4365079376463042: True (414.0)
# 2024-06-26: Betting on Tampa Bay Rays to beat Seattle Mariners with odds 0.4782608704725898: False (540.0)
# 2024-06-26: Betting on Cleveland Guardians to beat Baltimore Orioles with odds 0.630940342760865: False (440.0)
# 2024-06-26: Betting on New York Mets to beat New York Yankees with odds 0.4279403650712972: True (340.0)
# 2024-06-27: Betting on Minnesota Twins to beat Arizona Diamondbacks with odds 0.5324675324675324: True (472.0)
# 2024-06-27: Betting on Texas Rangers to beat Baltimore Orioles with odds 0.6574752256290606: False (558.0)
# 2024-06-27: Betting on Toronto Blue Jays to beat New York Yankees with odds 0.4485588865991627: True (458.0)
# 2024-06-28: Betting on Toronto Blue Jays to beat New York Yankees with odds 0.4782608704725898: False (578.0)
# 2024-06-28: Betting on Minnesota Twins to beat Seattle Mariners with odds 0.5427435386594943: False (478.0)
# 2024-06-29: Betting on San Diego Padres to beat Boston Red Sox with odds 0.5720596349287028: True (378.0)
# 2024-06-30: Betting on San Diego Padres to beat Boston Red Sox with odds 0.5427435386594943: False (451.0)
# 2024-06-30: Betting on Los Angeles Angels to beat Detroit Tigers with odds 0.5043297536554499: False (351.0)
# 2024-06-30: Betting on Minnesota Twins to beat Seattle Mariners with odds 0.5043297536554499: True (251.0)
# 2024-07-02: Betting on San Diego Padres to beat Texas Rangers with odds 0.5173641257223942: False (348.0)
# 2024-07-05: Betting on Chicago White Sox to beat Miami Marlins with odds 0.5217391295274103: True (248.0)
# 2024-07-06: Betting on Pittsburgh Pirates to beat New York Mets with odds 0.4485588865991627: False (338.0)
# 2024-07-07: Betting on Oakland Athletics to beat Baltimore Orioles with odds 0.369059657239135: False (238.0)
# 2024-07-07: Betting on Arizona Diamondbacks to beat San Diego Padres with odds 0.5933697527596193: True (138.0)
# (7, 8)
# 2024-07-10: Betting on Chicago Cubs to beat Baltimore Orioles with odds 0.6092362331597097: True (204.0)
# 2024-07-10: Betting on Pittsburgh Pirates to beat Milwaukee Brewers with odds 0.5829926396165348: False (267.0)
# 2024-07-11: Betting on Chicago Cubs to beat Baltimore Orioles with odds 0.5514411134008372: True (167.0)
# (7, 12)
# (7, 13)
# (7, 14)
# (7, 15)
# (7, 16)
# (7, 17)
# (9, 28)
# (9, 29)
# 388 783 0.4955300127713921

# %%
ovalues = np.array(ovalues)
plt.hist(ovalues[np.argsort(ovalues)],color='black',bins=50)
# Out:
# (array([ 1.,  0.,  0.,  2.,  0.,  0.,  1.,  3.,  6.,  7.,  6.,  7., 10.,
#          8., 20., 14., 16., 29., 31., 34., 35., 36., 36., 47., 48., 48.,
#         44., 43., 32., 34., 40., 29., 19., 18., 15., 15., 10., 12.,  9.,
#          4.,  5.,  3.,  3.,  1.,  0.,  0.,  0.,  0.,  1.,  1.]),
#  array([-0.38759842, -0.37318764, -0.35877687, -0.34436609, -0.32995532,
#         -0.31554454, -0.30113376, -0.28672299, -0.27231221, -0.25790144,
#         -0.24349066, -0.22907989, -0.21466911, -0.20025834, -0.18584756,
#         -0.17143679, -0.15702601, -0.14261524, -0.12820446, -0.11379369,
#         -0.09938291, -0.08497214, -0.07056136, -0.05615059, -0.04173981,
#         -0.02732904, -0.01291826,  0.00149251,  0.01590329,  0.03031406,
#          0.04472484,  0.05913561,  0.07354639,  0.08795716,  0.10236794,
#          0.11677872,  0.13118949,  0.14560027,  0.16001104,  0.17442182,
#          0.18883259,  0.20324337,  0.21765414,  0.23206492,  0.24647569,
#          0.26088647,  0.27529724,  0.28970802,  0.30411879,  0.31852957,
#          0.33294034]),
#  <BarContainer object of 50 artists>)
